# %% [markdown]
# ## Introduction
#
# If you're an active member of society, you've most likely heard of TikTok, if not post on it and watch videos. I personally watch TikToks, and have cousins as young as 9 who are on TikTok. I've seen how addictive and immersive it has become for millions of poeple. After seeing my little cousins making dance videos and learning that TikTokers are now a brand of right influencers, I wanted to learn more about what really makes these videos go viral. Is there a formula that gets videos seen on the algorithm? Is it a specific type of person? A common hashtag? Having people mentioned? What is it that makes TikToks go viral? I found that there are datasets for the top 1000 trending videos, so I wanted to use data science to see if there is something algorithmically that makes these videos "blow up", as the kids on TikTok say.

# %%
import json
import pandas as pd

#load the JSON from the current directory
data = json.load(open('trending.json'))

#turn the data into a pandas dataframe for easier analysis
df = pd.DataFrame(data['collector'])
df.sample(6)
# Out:
#                       id                                               text  \
# 362  6882870430625975557  Reply to @kay_is_here567 just like this lol ☺️...
# 953  6897643701426752770  #anime #animeedit #naruto #narutoedit #sasuke ...
# 13   6892769736589888770  Wist jij dit? 👀 #sportplazagroenendaal #zwemme...
# 392  6886119631011007745  #painting #oilpainting #artist #artwork #insta...
# 274  6900735754700459270  Reply to @jaredwiggins2832 #foryoupage #fyp #f...
# 930  6880694458552175874  Hit these to start your pull days #fyp #FallAe...
#
#      createTime                                         authorMeta  \
# 362  1602543187  {'id': '6702355218221483013', 'secUid': 'MS4wL...
# 953  1605982824  {'id': '6857933834689201158', 'secUid': 'MS4wL...
# 13   1604848016  {'id': '6829372384031900678', 'secUid': 'MS4wL...
# 392  1603299667  {'id': '6809671532438291461', 'secUid': 'MS4wL...
# 274  1606702780  {'id': '6809091326287905797', 'secUid': 'MS4wL...
# 930  1602036522  {'id': '6830062072786322437', 'secUid': 'MS4wL...
#
#                                              musicMeta  \
# 362  {'musicId': '6847647314127932166', 'musicName'...
# 953  {'musicId': '6897643703708551937', 'musicName'...
# 13   {'musicId': '6837446677348027141', 'musicName'...
# 392  {'musicId': '6845773926874745605', 'musicName'...
# 274  {'musicId': '6900735800871258886', 'musicName'...
# 930  {'musicId': '6880694412393974529', 'musicName'...
#
#                                                 covers  \
# 362  {'default': 'https://p16-sign-sg.tiktokcdn.com...
# 953  {'default': 'https://p16-sign-sg.tiktokcdn.com...
# 13   {'default': 'https://p16-sign-sg.tiktokcdn.com...
# 392  {'default': 'https://p16-sign-sg.tiktokcdn.com...
# 274  {'default': 'https://p16-sign-sg.tiktokcdn.com...
# 930  {'default': 'https://p16-sign-sg.tiktokcdn.com...
#
#                                            webVideoUrl  \
# 362  https://www.tiktok.com/@stephaniemorattooffici...
# 953  https://www.tiktok.com/@animexo/video/68976437...
# 13   https://www.tiktok.com/@sportplazagroenendaal/...
# 392  https://www.tiktok.com/@sumeyyecopoglu/video/6...
# 274  https://www.tiktok.com/@timmytimmadome/video/6...
# 930  https://www.tiktok.com/@evan_holmes_/video/688...
#
#                                               videoUrl videoUrlNoWaterMark  \
# 362  https://v77.tiktokcdn.com/0d804b364c30b212b845...
# 953  https://v77.tiktokcdn.com/ebb71cd138e711ef1815...
# 13   https://v77.tiktokcdn.com/d273f83a2b2b8d230e01...
# 392  https://v77.tiktokcdn.com/fa5c19535de113f89a2a...
# 274  https://v77.tiktokcdn.com/23eaa286eb3d2df52316...
# 930  https://v77.tiktokcdn.com/6dec494e5ec1277ea276...
#
#                                           videoMeta  diggCount  shareCount  \
# 362  {'height': 1024, 'width': 576, 'duration': 12}      25800          23
# 953  {'height': 576, 'width': 1024, 'duration': 10}      20500         657
# 13   {'height': 1024, 'width': 576, 'duration': 13}      57300         208
# 392   {'height': 1024, 'width': 576, 'duration': 9}      73300         747
# 274  {'height': 1024, 'width': 576, 'duration': 28}       9504          11
# 930   {'height': 720, 'width': 540, 'duration': 43}       2315         147
#
#      playCount  commentCount  downloaded             mentions  \
# 362     197700           217        True    [@kay_is_here567]
# 953     100800           527        True                   []
# 13     1200000           336        True                   []
# 392     295700           772        True                   []
# 274      78300           112        True  [@jaredwiggins2832]
# 930      35700            31        True                   []
#
#                                               hashtags
# 362  [{'id': '1679384911631366', 'name': 'rhymepov'...
# 953  [{'id': '5917', 'name': 'anime', 'title': '', ...
# 13   [{'id': '1659880875675654', 'name': 'sportplaz...
# 392  [{'id': '14057', 'name': 'painting', 'title': ...
# 274  [{'id': '88764338', 'name': 'foryoupage', 'tit...
# 930  [{'id': '229207', 'name': 'fyp', 'title': '', ...

# %% [markdown]
# We don't care much about anything other than views, mentions and hashtags, so we can clean the data up further

# %%
df.drop({'covers', 'downloaded', 'createTime', 'id', 'createTime', 'covers', 'musicMeta', 'authorMeta', \
         'webVideoUrl', 'videoUrl', 'videoUrlNoWaterMark', 'videoMeta', 'shareCount', 'diggCount', \
         'commentCount'}, axis=1, inplace=True)
df.sample(6)
# Out:
#                                                   text  playCount  \
# 445  no one wants to help me make a tikytoky so I f...      54900
# 353  #foryou #fyp #voorjou #wok #eten #koken #cooki...      40500
# 304                   😁🍻🥂 #foryoupage #fy #foryou #fyp      58600
# 369  Reply to @coolkid0183 #greenscreenvideo - it’s...      51500
# 205  Moet ik dit nog een keer proberen? 😂🤡 #foryou ...     175100
# 583  Vorige gerapporteerd, diegene mag zn teen stot...      80500
#
#            mentions                                           hashtags
# 445              []                                                 []
# 353              []  [{'id': '42164', 'name': 'foryou', 'title': ''...
# 304              []  [{'id': '88764338', 'name': 'foryoupage', 'tit...
# 369  [@coolkid0183]  [{'id': '79073378', 'name': 'greenscreenvideo'...
# 205              []  [{'id': '42164', 'name': 'foryou', 'title': ''...
# 583              []  [{'id': '42164', 'name': 'foryou', 'title': ''...

# %% [markdown]
# Now that we've wrangled the data and it is easier to work with, we can begin to analyze the correlation between mentions and playCount (views), and between hashtage and playCount. We can start by finding all hashtags used to see if any of them occur more than once, and doing the same with tags. We also have to take into account no tags and no mentions.

# %%
tags = dict()
mentions = dict()

for index, row in df.iterrows():
    m = row['mentions']
    t = row['hashtags']
    
    for men in m: 
        if men in mentions:
            i = mentions[men]
            mentions[men] = i+1
        else:
            mentions[men] = 1
    for ta in t: 
        name = ta['name']
        if name in tags:
            i = tags[name]
            tags[name] = i+1
        else:
            tags[name] = 1
            
#now, for organization, sort the array by the value, which represents the number of occurrences. 
tags = {k: v for k, v in sorted(tags.items(), key=lambda item: item[1])}
mentions = {k: v for k, v in sorted(mentions.items(), key=lambda item: item[1])}

i = 0
for k, v in tags.items(): 
    if i > len(tags) - 16:
        print(k, v)
    i+=1
i = 0
for k, v in mentions.items(): 
    if i > len(mentions) - 5:
        print(k, v)
    i+=1
# Out:
# powerlifting 39
# horadearrasar 40
# duet 40
# transition 43
# gym 49
# anime 50
# animeedit 63
# viral 65
# voorjou 72
# workout 73
# fitness 87
# fy 116
# foryoupage 174
# foryou 272
# fyp 417
# @gymshark 2
# @x 2
# @emmakeuven 2
# @bangenergy 2

# %% [markdown]
# As we can see from the hashtags, there is a strong sense of repition among them. However, for mentions, there is less repition. From this, I predict that the hashtags will have a stronger correlation to the number of views than the tags will. We can begin to graph these correlations, to see the total views per hashtag and per mention.

# %%
tags_by_views = dict()
ment_by_views = dict()
notags = 0
nomentions = 0

for index, row in df.iterrows():
    t = row['hashtags']
    m = row['mentions']
    
    if m == []:
        nomentions += row['playCount']
    for mention in m: 
        if mention in ment_by_views:
            i = ment_by_views[mention]
            ment_by_views[mention] = i+row['playCount']
        else:
            ment_by_views[mention] = row['playCount']
    if t == []:
        notags += row['playCount']
    for tag in t: 
        name = tag['name']
        if name in tags_by_views:
            i = tags_by_views[name]
            tags_by_views[name] = i+row['playCount']
        else:
            tags_by_views[name] = row['playCount']

tags_by_views = {k: v for k, v in sorted(tags_by_views.items(), key=lambda item: item[1])}
mentions = {k: v for k, v in sorted(mentions.items(), key=lambda item: item[1])}

# %% [markdown]
# Now that we've mapped hashtag and mention frequency and the number of views by hashtag and mention, we can map out frequency vs views

# %%
import matplotlib.pyplot as plt

views_by_freq_hashtag = dict()
views_by_freq_ment = dict()

for k, v in tags_by_views.items(): 
    for k2, v2 in tags.items():
        if k == k2:
            views_by_freq_hashtag[v2] = v
views_by_freq_hashtag[0] = notags

for k, v in ment_by_views.items(): 
    for k2, v2 in mentions.items():
        if k == k2:
            views_by_freq_ment[v2] = v
views_by_freq_hashtag[0] = notags
views_by_freq_ment[0] = nomentions

views = []
freqs = []
for k, v in views_by_freq_hashtag.items(): 
    views.append(v)
    freqs.append(k)
    
plt.scatter(freqs, views) 

plt.xlabel('Frequency of Hashtag') 
plt.ylabel('Number of Views (by 100 million)') 
plt.title('Number of Views by Frequency for Hashtags') 
    
plt.show() 

views = []
freqs = []
for k, v in views_by_freq_ment.items(): 
    views.append(v)
    freqs.append(k)
    
plt.scatter(freqs, views) 

plt.xlabel('Frequency of Hashtag') 
plt.ylabel('Number of Views (by 100 million)') 
plt.title('Number of Views by Frequency for Mentions') 
    
plt.show()

# %% [markdown]
# From looking at these plots, we can say that the frequency of mentions has a negative correlation with the number of views. At 0, there are 800,000,000 views, but that decreases to less than 200,000,000 as the mention frequency increases to 1 and 2. However, we can see that the hashtag plot has two linear correlations, one would be that a small frequency for a hashtag increases views, and the other is that the number of views increases as the frequency of the hashtag increases.
